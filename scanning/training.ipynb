# %% [markdown]
# ##  Path Setup ##

# %% [markdown]
# ##### Python 3.9 may only work for training #####

# %%
import os
import wget
import shutil

# %%
CUSTOM_MODEL_NAME = 'rs_windows_640x640' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'SCRIPTS_PATH': os.path.join('scripts'),
    'APIMODEL_PATH': '/home/mcserver/Desktop/machineLearning/tensorflow/research/object_detection/',
    'ANNOTATION_PATH': os.path.join('annotations'),
    'IMAGE_PATH': os.path.join('images'),
    'MODEL_PATH': os.path.join('models'),
    'PRETRAINED_MODEL_PATH': os.path.join('pretrained_models'),
    'CHECKPOINT_PATH': os.path.join('models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME),
    'TRAINING_SCRIPT' : os.path.join(paths['APIMODEL_PATH'], 'model_main_tf2.py')
}

# %% [markdown]
# ## Create Label Map ##

# %%
labels = [{'name':'balance', 'id': 1}, {'name':'content', 'id': 2}, {'name':'store', 'id': 3}, {'name':'details', 'id': 4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# ##  Create TF Records ##

# %%
if not os.path.exists(os.path.join(files['TF_RECORD_SCRIPT'])):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {os.path.join(paths['SCRIPTS_PATH'])}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: annotations/train.record
# Successfully created the TFRecord file: annotations/test.record

# %% [markdown]
# ## Download Pretrained Model ##

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2023-08-10 22:02:47--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 2607:f8b0:4007:814::2010, 142.250.68.48
# Connecting to download.tensorflow.org (download.tensorflow.org)|2607:f8b0:4007:814::2010|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20518283 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.57M  1.39MB/s    in 2m 45s
#
# 2023-08-10 22:05:36 (121 KB/s) - ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’ saved [20518283/20518283]
#
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# ## Copy and Move Config ##

# %%
if not os.path.exists(paths['CHECKPOINT_PATH']):
    os.mkdir(paths['CHECKPOINT_PATH'])

# %%
shutil.copy(os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config'), paths['CHECKPOINT_PATH'])
# Out:
# 'models/rs_windows_640x640/pipeline.config'

# %% [markdown]
# ## Update Config File ##

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=3000".format(files['TRAINING_SCRIPT'], paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
command
# Out:
# 'python /home/mcserver/Desktop/machineLearning/tensorflow/research/object_detection/model_main_tf2.py --model_dir=models/rs_640x640 --pipeline_config_path=models/rs_640x640/pipeline.config --num_train_steps=3000'

# %%
# test_path = os.path.join(paths["IMAGE_PATH"], "test") 
# classes = ["iphone", "samsung", "xiaomi", "pixel"]
# for file in os.listdir(test_path):
#     for label in classes:
#         if file.startswith(f"{label}_"):
#             new_name = f"{label}_" + file[len(label) + 1:]
#             new_name = os.path.join(test_path, new_name)
#             os.rename(os.path.join(test_path, file), new_name)

# %%
# Script to verify valid file types

from pathlib import Path
import imghdr

data_dir = os.path.join(paths["IMAGE_PATH"], "train") 
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
# !{command}
# Out:
# 2023-08-10 22:30:35.131340: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-10 22:30:35.215512: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-10 22:30:36.767317: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0810 22:30:39.800927 140257489655616 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 3000
# I0810 22:30:39.836269 140257489655616 config_util.py:552] Maybe overwriting train_steps: 3000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0810 22:30:39.836766 140257489655616 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0810 22:30:39.904689 140257489655616 deprecation.py:364] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['annotations/train.record']
# I0810 22:30:39.918855 140257489655616 dataset_builder.py:162] Reading unweighted datasets: ['annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/train.record']
# I0810 22:30:39.919153 140257489655616 dataset_builder.py:79] Reading record datasets for input file: ['annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0810 22:30:39.919239 140257489655616 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0810 22:30:39.919332 140257489655616 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0810 22:30:39.934271 140257489655616 deprecation.py:364] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0810 22:30:39.972956 140257489655616 deprecation.py:364] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0810 22:30:50.419641 140257489655616 deprecation.py:364] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0810 22:30:54.685208 140257489655616 deprecation.py:364] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0810 22:30:57.021692 140257489655616 deprecation.py:364] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-08-10 22:31:00.878152: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0810 22:31:09.029339 140254698792512 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0810 22:31:20.948024 140254698792512 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0810 22:31:32.028283 140254807832128 deprecation.py:569] From /home/mcserver/miniconda3/envs/tfrs/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0810 22:31:33.848838 140254807832128 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0810 22:31:42.313093 140254807832128 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0810 22:31:50.144382 140254807832128 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0810 22:31:58.197124 140254807832128 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# INFO:tensorflow:Step 100 per-step time 11.157s
# I0810 22:50:07.293931 140257489655616 model_lib_v2.py:705] Step 100 per-step time 11.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.3884908,
#  'Loss/localization_loss': 0.254095,
#  'Loss/regularization_loss': 0.15460071,
#  'Loss/total_loss': 0.7971865,
#  'learning_rate': 0.0319994}
# I0810 22:50:07.295765 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.3884908,
#  'Loss/localization_loss': 0.254095,
#  'Loss/regularization_loss': 0.15460071,
#  'Loss/total_loss': 0.7971865,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 8.970s
# I0810 23:05:04.177091 140257489655616 model_lib_v2.py:705] Step 200 per-step time 8.970s
# INFO:tensorflow:{'Loss/classification_loss': 0.4234262,
#  'Loss/localization_loss': 0.084638394,
#  'Loss/regularization_loss': 0.15433091,
#  'Loss/total_loss': 0.6623955,
#  'learning_rate': 0.0373328}
# I0810 23:05:04.177340 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.4234262,
#  'Loss/localization_loss': 0.084638394,
#  'Loss/regularization_loss': 0.15433091,
#  'Loss/total_loss': 0.6623955,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 8.226s
# I0810 23:18:46.797436 140257489655616 model_lib_v2.py:705] Step 300 per-step time 8.226s
# INFO:tensorflow:{'Loss/classification_loss': 0.43677986,
#  'Loss/localization_loss': 0.09446245,
#  'Loss/regularization_loss': 0.1539481,
#  'Loss/total_loss': 0.68519044,
#  'learning_rate': 0.0426662}
# I0810 23:18:46.797851 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.43677986,
#  'Loss/localization_loss': 0.09446245,
#  'Loss/regularization_loss': 0.1539481,
#  'Loss/total_loss': 0.68519044,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 11.601s
# I0810 23:38:06.871652 140257489655616 model_lib_v2.py:705] Step 400 per-step time 11.601s
# INFO:tensorflow:{'Loss/classification_loss': 0.2788804,
#  'Loss/localization_loss': 0.042368732,
#  'Loss/regularization_loss': 0.15357733,
#  'Loss/total_loss': 0.47482646,
#  'learning_rate': 0.047999598}
# I0810 23:38:06.872052 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.2788804,
#  'Loss/localization_loss': 0.042368732,
#  'Loss/regularization_loss': 0.15357733,
#  'Loss/total_loss': 0.47482646,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 7.418s
# I0810 23:50:28.641359 140257489655616 model_lib_v2.py:705] Step 500 per-step time 7.418s
# INFO:tensorflow:{'Loss/classification_loss': 0.31795454,
#  'Loss/localization_loss': 0.073968396,
#  'Loss/regularization_loss': 0.15323445,
#  'Loss/total_loss': 0.5451574,
#  'learning_rate': 0.053333}
# I0810 23:50:28.641807 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.31795454,
#  'Loss/localization_loss': 0.073968396,
#  'Loss/regularization_loss': 0.15323445,
#  'Loss/total_loss': 0.5451574,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 11.506s
# I0811 00:09:39.280612 140257489655616 model_lib_v2.py:705] Step 600 per-step time 11.506s
# INFO:tensorflow:{'Loss/classification_loss': 0.33222485,
#  'Loss/localization_loss': 0.048929367,
#  'Loss/regularization_loss': 0.15290162,
#  'Loss/total_loss': 0.5340558,
#  'learning_rate': 0.0586664}
# I0811 00:09:39.280879 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.33222485,
#  'Loss/localization_loss': 0.048929367,
#  'Loss/regularization_loss': 0.15290162,
#  'Loss/total_loss': 0.5340558,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 11.561s
# I0811 00:28:55.413872 140257489655616 model_lib_v2.py:705] Step 700 per-step time 11.561s
# INFO:tensorflow:{'Loss/classification_loss': 0.39299583,
#  'Loss/localization_loss': 0.042762965,
#  'Loss/regularization_loss': 0.15233624,
#  'Loss/total_loss': 0.58809507,
#  'learning_rate': 0.0639998}
# I0811 00:28:55.415073 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.39299583,
#  'Loss/localization_loss': 0.042762965,
#  'Loss/regularization_loss': 0.15233624,
#  'Loss/total_loss': 0.58809507,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 11.453s
# I0811 00:48:00.673447 140257489655616 model_lib_v2.py:705] Step 800 per-step time 11.453s
# INFO:tensorflow:{'Loss/classification_loss': 0.2981522,
#  'Loss/localization_loss': 0.07731571,
#  'Loss/regularization_loss': 0.15165932,
#  'Loss/total_loss': 0.52712727,
#  'learning_rate': 0.069333196}
# I0811 00:48:00.673764 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.2981522,
#  'Loss/localization_loss': 0.07731571,
#  'Loss/regularization_loss': 0.15165932,
#  'Loss/total_loss': 0.52712727,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 11.006s
# I0811 01:06:21.443842 140257489655616 model_lib_v2.py:705] Step 900 per-step time 11.006s
# INFO:tensorflow:{'Loss/classification_loss': 0.15183644,
#  'Loss/localization_loss': 0.14847869,
#  'Loss/regularization_loss': 0.15095083,
#  'Loss/total_loss': 0.45126596,
#  'learning_rate': 0.074666604}
# I0811 01:06:21.444641 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.15183644,
#  'Loss/localization_loss': 0.14847869,
#  'Loss/regularization_loss': 0.15095083,
#  'Loss/total_loss': 0.45126596,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 5.763s
# I0811 01:15:57.724596 140257489655616 model_lib_v2.py:705] Step 1000 per-step time 5.763s
# INFO:tensorflow:{'Loss/classification_loss': 0.23312803,
#  'Loss/localization_loss': 0.07345508,
#  'Loss/regularization_loss': 0.15023227,
#  'Loss/total_loss': 0.45681536,
#  'learning_rate': 0.08}
# I0811 01:15:57.725143 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23312803,
#  'Loss/localization_loss': 0.07345508,
#  'Loss/regularization_loss': 0.15023227,
#  'Loss/total_loss': 0.45681536,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 5.763s
# I0811 01:25:33.890805 140257489655616 model_lib_v2.py:705] Step 1100 per-step time 5.763s
# INFO:tensorflow:{'Loss/classification_loss': 0.2525479,
#  'Loss/localization_loss': 0.014759424,
#  'Loss/regularization_loss': 0.14942572,
#  'Loss/total_loss': 0.41673303,
#  'learning_rate': 0.07999918}
# I0811 01:25:33.891271 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.2525479,
#  'Loss/localization_loss': 0.014759424,
#  'Loss/regularization_loss': 0.14942572,
#  'Loss/total_loss': 0.41673303,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 5.756s
# I0811 01:35:09.481041 140257489655616 model_lib_v2.py:705] Step 1200 per-step time 5.756s
# INFO:tensorflow:{'Loss/classification_loss': 0.27124095,
#  'Loss/localization_loss': 0.039380454,
#  'Loss/regularization_loss': 0.14857838,
#  'Loss/total_loss': 0.4591998,
#  'learning_rate': 0.079996705}
# I0811 01:35:09.481484 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.27124095,
#  'Loss/localization_loss': 0.039380454,
#  'Loss/regularization_loss': 0.14857838,
#  'Loss/total_loss': 0.4591998,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 5.759s
# I0811 01:44:45.336807 140257489655616 model_lib_v2.py:705] Step 1300 per-step time 5.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.33790597,
#  'Loss/localization_loss': 0.13081387,
#  'Loss/regularization_loss': 0.14772542,
#  'Loss/total_loss': 0.6164453,
#  'learning_rate': 0.0799926}
# I0811 01:44:45.337074 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.33790597,
#  'Loss/localization_loss': 0.13081387,
#  'Loss/regularization_loss': 0.14772542,
#  'Loss/total_loss': 0.6164453,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 5.743s
# I0811 01:54:19.590700 140257489655616 model_lib_v2.py:705] Step 1400 per-step time 5.743s
# INFO:tensorflow:{'Loss/classification_loss': 0.26009175,
#  'Loss/localization_loss': 0.0037411451,
#  'Loss/regularization_loss': 0.14683722,
#  'Loss/total_loss': 0.4106701,
#  'learning_rate': 0.07998685}
# I0811 01:54:19.590947 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.26009175,
#  'Loss/localization_loss': 0.0037411451,
#  'Loss/regularization_loss': 0.14683722,
#  'Loss/total_loss': 0.4106701,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 5.746s
# I0811 02:03:54.240730 140257489655616 model_lib_v2.py:705] Step 1500 per-step time 5.746s
# INFO:tensorflow:{'Loss/classification_loss': 0.27353433,
#  'Loss/localization_loss': 0.0055773603,
#  'Loss/regularization_loss': 0.14592782,
#  'Loss/total_loss': 0.4250395,
#  'learning_rate': 0.07997945}
# I0811 02:03:54.241018 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.27353433,
#  'Loss/localization_loss': 0.0055773603,
#  'Loss/regularization_loss': 0.14592782,
#  'Loss/total_loss': 0.4250395,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 5.744s
# I0811 02:13:28.859516 140257489655616 model_lib_v2.py:705] Step 1600 per-step time 5.744s
# INFO:tensorflow:{'Loss/classification_loss': 0.22749384,
#  'Loss/localization_loss': 0.008910308,
#  'Loss/regularization_loss': 0.14502038,
#  'Loss/total_loss': 0.38142455,
#  'learning_rate': 0.079970405}
# I0811 02:13:28.859808 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.22749384,
#  'Loss/localization_loss': 0.008910308,
#  'Loss/regularization_loss': 0.14502038,
#  'Loss/total_loss': 0.38142455,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 5.747s
# I0811 02:23:03.265773 140257489655616 model_lib_v2.py:705] Step 1700 per-step time 5.747s
# INFO:tensorflow:{'Loss/classification_loss': 0.23541749,
#  'Loss/localization_loss': 0.008369714,
#  'Loss/regularization_loss': 0.14412831,
#  'Loss/total_loss': 0.3879155,
#  'learning_rate': 0.07995972}
# I0811 02:23:03.266044 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23541749,
#  'Loss/localization_loss': 0.008369714,
#  'Loss/regularization_loss': 0.14412831,
#  'Loss/total_loss': 0.3879155,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 5.781s
# I0811 02:32:41.383525 140257489655616 model_lib_v2.py:705] Step 1800 per-step time 5.781s
# INFO:tensorflow:{'Loss/classification_loss': 0.17964232,
#  'Loss/localization_loss': 0.13252702,
#  'Loss/regularization_loss': 0.14323147,
#  'Loss/total_loss': 0.45540082,
#  'learning_rate': 0.0799474}
# I0811 02:32:41.383819 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.17964232,
#  'Loss/localization_loss': 0.13252702,
#  'Loss/regularization_loss': 0.14323147,
#  'Loss/total_loss': 0.45540082,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 5.753s
# I0811 02:42:16.721131 140257489655616 model_lib_v2.py:705] Step 1900 per-step time 5.753s
# INFO:tensorflow:{'Loss/classification_loss': 0.18134491,
#  'Loss/localization_loss': 0.0019483535,
#  'Loss/regularization_loss': 0.14234404,
#  'Loss/total_loss': 0.3256373,
#  'learning_rate': 0.07993342}
# I0811 02:42:16.721385 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.18134491,
#  'Loss/localization_loss': 0.0019483535,
#  'Loss/regularization_loss': 0.14234404,
#  'Loss/total_loss': 0.3256373,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 5.789s
# I0811 02:51:55.607997 140257489655616 model_lib_v2.py:705] Step 2000 per-step time 5.789s
# INFO:tensorflow:{'Loss/classification_loss': 0.28029197,
#  'Loss/localization_loss': 0.0013529282,
#  'Loss/regularization_loss': 0.14145108,
#  'Loss/total_loss': 0.42309597,
#  'learning_rate': 0.07991781}
# I0811 02:51:55.608262 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.28029197,
#  'Loss/localization_loss': 0.0013529282,
#  'Loss/regularization_loss': 0.14145108,
#  'Loss/total_loss': 0.42309597,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 5.749s
# I0811 03:01:30.707041 140257489655616 model_lib_v2.py:705] Step 2100 per-step time 5.749s
# INFO:tensorflow:{'Loss/classification_loss': 0.22695881,
#  'Loss/localization_loss': 0.0035972467,
#  'Loss/regularization_loss': 0.14056839,
#  'Loss/total_loss': 0.37112445,
#  'learning_rate': 0.07990056}
# I0811 03:01:30.707314 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.22695881,
#  'Loss/localization_loss': 0.0035972467,
#  'Loss/regularization_loss': 0.14056839,
#  'Loss/total_loss': 0.37112445,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 5.751s
# I0811 03:11:05.623746 140257489655616 model_lib_v2.py:705] Step 2200 per-step time 5.751s
# INFO:tensorflow:{'Loss/classification_loss': 0.23587775,
#  'Loss/localization_loss': 0.00349645,
#  'Loss/regularization_loss': 0.13969433,
#  'Loss/total_loss': 0.37906855,
#  'learning_rate': 0.07988167}
# I0811 03:11:05.624032 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23587775,
#  'Loss/localization_loss': 0.00349645,
#  'Loss/regularization_loss': 0.13969433,
#  'Loss/total_loss': 0.37906855,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 5.747s
# I0811 03:20:40.364380 140257489655616 model_lib_v2.py:705] Step 2300 per-step time 5.747s
# INFO:tensorflow:{'Loss/classification_loss': 0.2249149,
#  'Loss/localization_loss': 0.0026084918,
#  'Loss/regularization_loss': 0.13883191,
#  'Loss/total_loss': 0.3663553,
#  'learning_rate': 0.07986114}
# I0811 03:20:40.364646 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.2249149,
#  'Loss/localization_loss': 0.0026084918,
#  'Loss/regularization_loss': 0.13883191,
#  'Loss/total_loss': 0.3663553,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 5.758s
# I0811 03:30:16.148263 140257489655616 model_lib_v2.py:705] Step 2400 per-step time 5.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.24547134,
#  'Loss/localization_loss': 0.013203314,
#  'Loss/regularization_loss': 0.13797255,
#  'Loss/total_loss': 0.3966472,
#  'learning_rate': 0.07983897}
# I0811 03:30:16.148522 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.24547134,
#  'Loss/localization_loss': 0.013203314,
#  'Loss/regularization_loss': 0.13797255,
#  'Loss/total_loss': 0.3966472,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 5.754s
# I0811 03:39:51.530122 140257489655616 model_lib_v2.py:705] Step 2500 per-step time 5.754s
# INFO:tensorflow:{'Loss/classification_loss': 0.18532091,
#  'Loss/localization_loss': 0.0010978499,
#  'Loss/regularization_loss': 0.1371141,
#  'Loss/total_loss': 0.32353285,
#  'learning_rate': 0.079815164}
# I0811 03:39:51.530480 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.18532091,
#  'Loss/localization_loss': 0.0010978499,
#  'Loss/regularization_loss': 0.1371141,
#  'Loss/total_loss': 0.32353285,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 5.768s
# I0811 03:49:28.341166 140257489655616 model_lib_v2.py:705] Step 2600 per-step time 5.768s
# INFO:tensorflow:{'Loss/classification_loss': 0.28826046,
#  'Loss/localization_loss': 0.0018062132,
#  'Loss/regularization_loss': 0.13625309,
#  'Loss/total_loss': 0.42631978,
#  'learning_rate': 0.07978972}
# I0811 03:49:28.341452 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.28826046,
#  'Loss/localization_loss': 0.0018062132,
#  'Loss/regularization_loss': 0.13625309,
#  'Loss/total_loss': 0.42631978,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 5.762s
# I0811 03:59:04.558248 140257489655616 model_lib_v2.py:705] Step 2700 per-step time 5.762s
# INFO:tensorflow:{'Loss/classification_loss': 0.2551177,
#  'Loss/localization_loss': 0.0065385015,
#  'Loss/regularization_loss': 0.13539532,
#  'Loss/total_loss': 0.3970515,
#  'learning_rate': 0.07976264}
# I0811 03:59:04.558506 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.2551177,
#  'Loss/localization_loss': 0.0065385015,
#  'Loss/regularization_loss': 0.13539532,
#  'Loss/total_loss': 0.3970515,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 5.761s
# I0811 04:08:40.705611 140257489655616 model_lib_v2.py:705] Step 2800 per-step time 5.761s
# INFO:tensorflow:{'Loss/classification_loss': 0.32290465,
#  'Loss/localization_loss': 0.0022226942,
#  'Loss/regularization_loss': 0.13454542,
#  'Loss/total_loss': 0.45967275,
#  'learning_rate': 0.07973392}
# I0811 04:08:40.705883 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.32290465,
#  'Loss/localization_loss': 0.0022226942,
#  'Loss/regularization_loss': 0.13454542,
#  'Loss/total_loss': 0.45967275,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 5.745s
# I0811 04:18:15.219829 140257489655616 model_lib_v2.py:705] Step 2900 per-step time 5.745s
# INFO:tensorflow:{'Loss/classification_loss': 0.23671427,
#  'Loss/localization_loss': 0.0026381146,
#  'Loss/regularization_loss': 0.13370198,
#  'Loss/total_loss': 0.3730544,
#  'learning_rate': 0.07970358}
# I0811 04:18:15.220099 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23671427,
#  'Loss/localization_loss': 0.0026381146,
#  'Loss/regularization_loss': 0.13370198,
#  'Loss/total_loss': 0.3730544,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 5.784s
# I0811 04:27:53.820380 140257489655616 model_lib_v2.py:705] Step 3000 per-step time 5.784s
# INFO:tensorflow:{'Loss/classification_loss': 0.24326776,
#  'Loss/localization_loss': 0.0067944904,
#  'Loss/regularization_loss': 0.13286714,
#  'Loss/total_loss': 0.38292938,
#  'learning_rate': 0.0796716}
# I0811 04:27:53.821015 140257489655616 model_lib_v2.py:708] {'Loss/classification_loss': 0.24326776,
#  'Loss/localization_loss': 0.0067944904,
#  'Loss/regularization_loss': 0.13286714,
#  'Loss/total_loss': 0.38292938,
#  'learning_rate': 0.0796716}

# %% [markdown]
# ## Evaluate Model ##

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(files['TRAINING_SCRIPT'], paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
# !{command}

# %% [markdown]
# ## Detection Image Test ##

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util
# Out:
# 2023-08-12 18:50:14.109823: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-12 18:50:14.340355: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-12 18:50:16.672957: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-4')).expect_partial()

def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
from PIL import Image
# Reciept images: (1655, 7047)
# Valid images: (1280, 720)
# Current: (413, 2056) <- (413, 1312)

def resize_images(path: str, factor: int):
    for file_name in os.listdir(path):
        if file_name.endswith(".jpg"):
            file_path = os.path.join(path, file_name)
            image = Image.open(file_path)
            width, height = image.size
            target_size = (int(width//factor), int(height//factor))
            resized_image = image.resize(target_size, Image.LANCZOS)
            resized_image.save(file_path)

def show_images_size(path: str):
    for file_name in os.listdir(path):
        if file_name.endswith(".jpg"):
            file_path = os.path.join(path, file_name)
            image = Image.open(file_path)
            print(image.size)

def remove_xml(path: str):
    for file_name in os.listdir(path):
        if file_name.endswith(".xml"):
            os.remove(os.path.join(path, file_name))

# %%
TESTING_IMAGES_PATH = os.path.join(paths['IMAGE_PATH'], 'collected','raw')
resize_images(TESTING_IMAGES_PATH, 0.25)

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'train', 'balance_6028e636-33e1-11ee-a805-984827e0aa99.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)


num_detections = int(detections.pop('num_detections'))

print(num_detections)
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

plt.figure(figsize=(5, 10))
viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.2,
            agnostic_mode=False)

wahat = cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB)
plt.imshow(wahat)
plt.show()
# Out:
# 100
